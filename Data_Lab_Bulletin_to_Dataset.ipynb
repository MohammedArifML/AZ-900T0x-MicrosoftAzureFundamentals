# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedArifML/AZ-900T0x-MicrosoftAzureFundamentals/blob/master/Data_Lab_Bulletin_to_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import zipfile

# %%
with zipfile.ZipFile('/content/Chapter 11 Environmental Statistics.zip', 'r') as zip_ref:
  zip_ref.extractall('/content/')

# %% [markdown]
# # Step 1:

# %% [markdown]
# Read excel files and create a list of dataframes out of them

# %%
# important
pds=[]
os.getcwd


path=os.getcwd()
path='/content/Chapter 11 Environmental Statistics/Excel/'
files = os.listdir(path)
x=[]
xy=[]
print(files)
for f in files:
  if f.endswith('.xls') or f.endswith('.xlsx'):
    print(path+f)
    #print(f.split(sep='_')[-2],pd.ExcelFile(path+f).sheet_names)
    x.append({'year': f.split(sep='_')[-2], 'file_path':path+f, 'sheet_names':pd.ExcelFile(path+f).sheet_names})
    xy.append(pd.Series([str(path+f),','.join(pd.ExcelFile(str(path+f)).sheet_names)],name=f.split(sep='_')[-2],index=['file path','sheet names']))


pd.DataFrame(x)
# Out:
# ['Environment_11_2017_AE.xlsx', 'Environment_11_2012_AE.xls', 'Environment_11_2015_AE.xlsx', 'Environment_11_2020_AE.xlsx', 'Environment_11_2016_AE.xlsx', 'Environment_11_2022_AE.xlsx', 'Environment_11_2018_AE.xlsx', '.ipynb_checkpoints', 'Environment_11_2014_AE.xlsx', 'Environment_11_2019_AE.xlsx', 'Environment_11_2023_AE.xlsx']
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2017_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2012_AE.xls
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2015_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2020_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2016_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2022_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2018_AE.xlsx
# /content/Chapter 11 Environmental Statistics/Excel/Environment_11_2014_AE.xlsx
# ...

# %%
test1=pd.read_excel('/content/Chapter 11 Environmental Statistics/Excel/Environment_11_2023_AE.xlsx',sheet_name='240',na_filter=False)
df=pd.DataFrame(test1)
heading_num=df['Unnamed: 1'].isna().cumprod().sum() # get the number of heading rows
heading_num=df['Unnamed: 1'].eq('').cumprod().sum()
year=df[:heading_num].iloc[-2].iloc[0]
variable=df[:heading_num].iloc[-3].iloc[0]
eng_title=df[:heading_num].iloc[-4].iloc[0]
if year == eng_title:
  eng_title=variable
  print('year:', year, 'title:', eng_title)
else:
  print('year:', year, 'title:', eng_title, 'variable: ',variable)
df.replace('',np.nan)
# Out:
# year: 2023 title: PERCENTAGE DISTRIBUTION OF DAILY MONITORING OF AIR QUALITY INDICATORS variable:  MOVENPICK (AL CORNICHE)
#      التوزيع النسبي للرصد اليومي لمؤشرات جودة الهواء  Unnamed: 1 Unnamed: 2  \
# 0                                 موفينبيك (الكورنيش)        NaN        NaN
# 1                                                2023        NaN        NaN
# 2   PERCENTAGE DISTRIBUTION OF DAILY MONITORING OF...        NaN        NaN
# 3                             MOVENPICK (AL CORNICHE)        NaN        NaN
# 4                                                2023        NaN        NaN
# 5                                     جدول رقم (240)         NaN        NaN
# 6                                وصف المؤشر\n\nالملوث       نظيف     طبيعي
# 7                                                 NaN      Clean     Normal
# 8                           ثنائي أكسيد الكبريت (SO2)          1          0
# 9                        ثنائي أكسيد النيتروجين (NO2)      0.986      0.014
# ...

# %% [markdown]
# # Step 2:

# %%
# important
def get_data_frame(full_path,sheetname):
  test=pd.read_excel(full_path,sheet_name=sheetname)
  df=pd.DataFrame(test)
  try:
    title_arabic=df.iloc[1]['Unnamed: 0'] # gets year
    year=df.iloc[2]['Unnamed: 0'] # gets port name
    title_english=df.iloc[3]['Unnamed: 0'] # gets table tilte

    df.ffill(inplace=True) # replaces NaN values caused by merged cells
    col_names=df.iloc[7]

    #df.set_axis(df.iloc[7].values,axis='columns').dropna().melt(col_level=0)
    df=df.dropna().melt(id_vars=['Unnamed: 0', 'Unnamed: 1'])
    col_names.replace(to_replace="$(\n)",value="",regex=True, inplace=True)
    col_names
    df.replace(col_names.index,col_names.values,inplace=True)
    df = df[pd.to_numeric(df['value'], errors='coerce').notna()]
    df=df[df['Unnamed: 0'] != 'Total'][df['Unnamed: 1'] != 'Total'][df['variable'] != 'Total']
    #col_names
    df.rename(columns=col_names,inplace=True)
    df.insert(0, "Title in Arabic", year)
    df.insert(1,"Year",port)
    df.insert(2, "Table title", table_title)
    return df
  except:
    return df
dfs=[]
for el in x:
  for sheets in el['sheet_names']:
    #print(sheets)
    #print(el['file_path'])
    dataframe_table=get_data_frame(el['file_path'],sheets)
    dfs.append(dataframe_table)
#sheets_df=pd.DataFrame(x)
dfs[6]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-91c633088ee6> in <cell line: 0>()
#      30     #print(sheets)
#      31     #print(el['file_path'])
# ---> 32     dataframe_table=get_data_frame(el['file_path'],sheets)
#      33     dfs.append(dataframe_table)
#      34 #sheets_df=pd.DataFrame(x)
#
# <ipython-input-32-91c633088ee6> in get_data_frame(full_path, sheetname)
#       1 # important
#       2 def get_data_frame(full_path,sheetname):
# ----> 3   test=pd.read_excel(full_path,sheet_name=sheetname)
#       4   df=pd.DataFrame(test)
#       5   try:
#
# ...

# %%
dfs[148]
# Out:
#                                             Table title  \
# 185   Arriving Vessels' Gross and Net Tonnage By Typ...
# 186   Arriving Vessels' Gross and Net Tonnage By Typ...
# 187   Arriving Vessels' Gross and Net Tonnage By Typ...
# 188   Arriving Vessels' Gross and Net Tonnage By Typ...
# 189   Arriving Vessels' Gross and Net Tonnage By Typ...
# ...                                                 ...
# 1822  Arriving Vessels' Gross and Net Tonnage By Typ...
# 1823  Arriving Vessels' Gross and Net Tonnage By Typ...
# 1824  Arriving Vessels' Gross and Net Tonnage By Typ...
# 1825  Arriving Vessels' Gross and Net Tonnage By Typ...
# 1829  Arriving Vessels' Gross and Net Tonnage By Typ...
#
#                                 Country of Registration  Year  \
# 185                                               QATAR  2023
# 186                                               QATAR  2023
# 187                                               QATAR  2023
# ...

# %%
# important
table_titles=[]
for dataframe in dfs:
  try:
    table_titles.append(dataframe['Table title'].unique()[0])

  except:
    print('')
set(table_titles)
final_dfs=[]
for title in set(table_titles):
  temp_df=pd.DataFrame()
  for dataframe in dfs:
    if 'Table title' in dataframe.columns:
      #print(dataframe['Table title'])
      if title in dataframe['Table title'].values:
          temp_df=pd.concat([temp_df,dataframe])
  final_dfs.append(temp_df)

len(final_dfs)
# Out:
# 3

# %%
for df in final_dfs:
  df.to_excel(df['Table title'].unique()[0]+".xlsx")

# %% [markdown]
# # Ignore Code Below

# %%
for el in x:
  print(el)
  for sheets in el['sheet_names']:
    #print(sheets)
    #print(el['file_path'])
    print(sheets)
    excel_file=pd.read_excel(el['file_path'], sheet_name=sheets)
    df_1=pd.DataFrame(excel_file,name=excel_file['Unnamed: 0'][3])
    df_1
# Out:
# {'year': '2018', 'file_path': '/content/Navigation Traffic/Excel/Navigation_Traffic_2018_AE.xlsx', 'sheet_names': ['Sheet1', 'Frst', 'Preface', 'Indx', 'Introduction', 'CH1', '1_1', '1-2', '1_3', '1-4', '1_5 ', '1_6', 'CH2', '2_1', '2_2', '2_3', '2_4', '2_5', '2_6 ', 'Gr-1', 'Gr-2', 'Annex', 'Qucst.']}
# Sheet1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9178996ec655> in <cell line: 0>()
#       6     print(sheets)
#       7     excel_file=pd.read_excel(el['file_path'], sheet_name=sheets)
# ----> 8     df_1=pd.DataFrame(excel_file,name=excel_file['Unnamed: 0'][3])
#       9     df_1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
# ...

# %%
test=pd.read_excel("/content/Navigation Traffic/Excel/Navigation_Traffic_2018_AE.xlsx","1_1")
df=pd.DataFrame(test)
year=df.iloc[2]['Unnamed: 0'] # gets year
table_title=df.iloc[1]['Unnamed: 0'] # gets table tilte
port=df.iloc[3]['Unnamed: 0'] # gets port name
table_title_ar=df.iloc[0]['Unnamed: 0'] # gets table title in arabic

df.ffill(inplace=True) # replaces NaN values caused by merged cells
#col_names=df.iloc[7]
df.dropna()
# Out:
#                  Unnamed: 0        Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 6   Country of Registration  Number & Tonnage  المجــمــوع  أخـــــرى
# 7   Country of Registration  Number & Tonnage        Total     Others
# 8                     QATAR    No. of Vessels           45         45
# 9                     QATAR     Gross Tonnage        21831      21831
# 10                    QATAR       Net Tonnage         8732       8732
# ..                      ...               ...          ...        ...
# 78               NOT STATED     Gross Tonnage           37         37
# 79               NOT STATED       Net Tonnage           37         37
# 80                    Total    No. of Vessels          131         82
# 81                    Total     Gross Tonnage      3207874     487691
# 82                    Total       Net Tonnage      2073834     346760
#
#               Unnamed: 4          Unnamed: 5    Unnamed: 6         Unnamed: 7  \
# ...

# %%
pds[7]
# Out:
#                                             Unnamed: 0      Unnamed: 1  \
# 0    السفن القادمة وحمولتها الإجمالية والصافية بالط...             NaN
# 1    Arriving Vessels' Gross and Net Tonnage By Typ...             NaN
# 2                                                 2019             NaN
# 3                          ميناء مسيعيد  Mesaieed Port             NaN
# 4                                     Table No (1 - 2)             NaN
# ..                                                 ...             ...
# 147                                                NaN   Gross Tonnage
# 148                                                NaN     Net Tonnage
# 149                                              Total  No. of Vessels
# 150                                                NaN   Gross Tonnage
# 151                                                NaN     Net Tonnage
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
files = os.listdir(path)
for file in files:
  print(file)
# Out:
# Navigation_Traffic_2019_AE.xlsx
# Navigation_Traffic_2023_AE.xlsx
# Navigation_Traffic_2018_AE.xlsx
# Navigation_Traffic_2016_AE.xlsx
# Navigation_Traffic_2021_AE.xlsx
# Navigation_Traffic_2020_AE.xlsx
# Navigation_Traffic_2017_AE.xlsx
# 'Qucst.'

# %%
def get_data_frame(full_path,sheetname):
  test=pd.read_excel(full_path,sheet_name=sheetname)
  df=pd.DataFrame(test)
  year=df.iloc[2]['Unnamed: 0']
  table_title=df.iloc[1]['Unnamed: 0']
  port=df.iloc[3]['Unnamed: 0']
  df.ffill(inplace=True) # replaces NaN values caused by merged cells
  col_names=df.iloc[7]

  #df.set_axis(df.iloc[7].values,axis='columns').dropna().melt(col_level=0)
  df=df.dropna().melt(id_vars=['Unnamed: 0', 'Unnamed: 1'])
  col_names.replace(to_replace="$(\n)",value="",regex=True, inplace=True)
  col_names
  df.replace(col_names.index,col_names.values,inplace=True)
  df = df[pd.to_numeric(df['value'], errors='coerce').notna()]
  df=df[df['Unnamed: 0'] != 'Total'][df['Unnamed: 0'] != 'Total'][df['variable'] != 'Total']
  #col_names
  df.rename(columns=col_names,inplace=True)
  df.insert(1, "Year", year)
  df.insert(2,"Port",port)
  df.insert(0, "Table title", table_title)
  return df

# %%
pds=[]
for el in nav_df['file path']:
  print(el)
  pds.append(pd.read_excel(el, sheet_name=sheets))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-876d67b817de> in <cell line: 0>()
#       1 pds=[]
# ----> 2 for el in nav_df['file path']:
#       3   print(el)
#       4   pds.append(pd.read_excel(el, sheet_name=sheets))
#
# NameError: name 'nav_df' is not defined

# %%
pds[6]
for el in x:
  for sheets in el['sheet_names']:
    #print(sheets)
    #print(el['file_path'])
    pds.append(pd.read_excel(el['file_path'], sheet_name=sheets))
# Out:
#                                            Unnamed: 0      Unnamed: 1  \
# 0   السفن القادمة وحمولتها الإجمالية والصافية بالط...             NaN
# 1   Arriving Vessels' Gross and Net Tonnage By Typ...             NaN
# 2                                                2019             NaN
# 3                             ميناء الدوحة  Doha Port             NaN
# 4                                    Table No (1 - 1)             NaN
# ..                                                ...             ...
# 60                                                NaN   Gross Tonnage
# 61                                                NaN     Net Tonnage
# 62                                              Total  No. of Vessels
# 63                                                NaN   Gross Tonnage
# 64                                                NaN     Net Tonnage
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
test_births=pd.read_excel('/content/Births and Deaths/Bulletin_Births_Deaths_2013_AE.xlsx',sheet_name='5',header=[4,5],index_col=[0]) #header=[4,5] multiindexing subcolumns

df_births=pd.DataFrame(test_births)
col_names=df_births.iloc[4]
df_births.replace(to_replace="$(\n)",value="",regex=True, inplace=True)
#df_births.replace(col_names.index,col_names.values,inplace=True)

#df_births=df_births.ffill(axis='columns').melt(id_vars=[0],value_vars=[1,2,3,4,5,6,7,8])
#df_births.replace(col_names.index,col_names.values,inplace=True)
#df_births = df_births[pd.to_numeric(df_births['value'], errors='coerce').notna()]
#df_births
df_births=df_births.melt(ignore_index=False)
df_births
# Out:
#                              Nationality & Gender\n\n\n  Year                       \
# 2004                                              المجموع\nTotal
# 2005                                              المجموع\nTotal
# 2006                                              المجموع\nTotal
# 2007                                              المجموع\nTotal
# 2008                                              المجموع\nTotal
# ...                                                          ...
# 2013                                   الجنسية والنوع\n \n السنة
# 2013                                   الجنسية والنوع\n \n السنة
# 2013                                   الجنسية والنوع\n \n السنة
# 2013                                   الجنسية والنوع\n \n السنة
# إناث\nFemales                          الجنسية والنوع\n \n السنة
#
#                               None value
# 2004                      مجموع\nT  10.4
# 2005                      مجموع\nT  10.5
# 2006                      مجموع\nT  10.7
# ...
